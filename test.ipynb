# %% [markdown]
# # Environment Test
#
# This notebook tests that your setup is correct to run the tutorial notebooks.
# You should already have already have Dragon installed in a Python environment.
# Try running this next cell to see that you are ready to run the jupyter notebooks
# in this tutorial.

# %%
import dragon
import multiprocessing as mp

# This is needed when running Dragon. You import dragon (as on the first line above) and then
# you set the multiprocessing start method to "dragon".
mp.set_start_method("dragon")

from dragon.data.ddict import DDict
print("Dragon ready ✓")

# %% [markdown]
# Assuming that "Dragon ready" was printed above, you are all set!
